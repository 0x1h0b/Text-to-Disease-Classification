# %%
import pandas as pd
import numpy
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# load the dataset
data = {
            "ds" : "./../data/raw_data/dataset.csv",
            "s_des" : "./../data/raw_data/symptom_description.csv",
            "s_pre" : "./../data/raw_data/symptom_precaution.csv",
            "s_sev" : "./../data/raw_data/symptom_severity.csv"
        }


ds = pd.read_csv(data['ds'])
s_des = pd.read_csv(data["s_des"])
s_pre = pd.read_csv(data["s_pre"])
s_sev = pd.read_csv(data["s_sev"])

print("size of ds : ",ds.shape)
print("size of s_des : ",s_des.shape)
print("size of s_pre : ",s_pre.shape)
print("size of s_sev : ",s_sev.shape)
# Out:
# size of ds :  (4920, 18)
# size of s_des :  (41, 2)
# size of s_pre :  (41, 5)
# size of s_sev :  (133, 2)

# %% [markdown]
# # Data exploration
#
# ### dataset (ds)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
ds.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
ds['Disease'].value_counts()
# Out:
# Fungal infection                           120
# Hepatitis C                                120
# Hepatitis E                                120
# Alcoholic hepatitis                        120
# Tuberculosis                               120
# Common Cold                                120
# Pneumonia                                  120
# Dimorphic hemmorhoids(piles)               120
# Heart attack                               120
# Varicose veins                             120
# Hypothyroidism                             120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Osteoarthristis                            120
# Arthritis                                  120
# (vertigo) Paroymsal  Positional Vertigo    120
# Acne                                       120
# Urinary tract infection                    120
# Psoriasis                                  120
# Hepatitis D                                120
# Hepatitis B                                120
# Allergy                                    120
# hepatitis A                                120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# Impetigo                                   120
# Name: Disease, dtype: int64

# %%
def cnt_plot_symptom(col):
    plt.figure(figsize=(30,17))
    plt.grid(True)
    g = sns.countplot(data=ds,x=col)
    for p in g.patches:
        txt = str(p.get_height())
        g.annotate(txt,(p.get_x()+0.01, p.get_height()))
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
cnt_plot_symptom("Symptom_1")

# %%
cnt_plot_symptom("Symptom_2")

# %%
cnt_plot_symptom("Symptom_3")

# %%
cnt_plot_symptom("Symptom_4")

# %%
# leave your comments and thoughts based on data

# %% [markdown]
# ### symptom description (s_des)

# %%
# symptom description
s_des.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
s_des.isnull().sum()
# Out:
# Disease        0
# Description    0
# dtype: int64

# %%
x1=sorted(list(set(s_des['Disease'].values)))
x2=sorted(list(set(ds['Disease'].values)))

for i in range(len(x1)):
    if x1[i]!=x2[i]:
        print(x1[i],"=======",x2[i])
# Out:
# Diabetes ======= Diabetes
# Dimorphic hemorrhoids(piles) ======= Dimorphic hemmorhoids(piles)
# Hypertension ======= Hypertension

# %% [markdown]
# s_des diseases are all the same as main dataset diseases ,
# but these 3 are different which is simple miss typing for 1 and extra space for 2 (which can be handled by strip()).

# %%
# correcting the spelling mistake
s_des.replace({'Dimorphic hemorrhoids(piles)': "Dimorphic hemmorhoids(piles)"},inplace=True)

# %% [markdown]
# ### symptom precaution (s_pre)

# %%
# symptom precaution
s_pre.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
s_pre.isnull().sum()
# Out:
# Disease         0
# Precaution_1    0
# Precaution_2    0
# Precaution_3    1
# Precaution_4    1
# dtype: int64

# %%
x1=sorted(list(set(s_pre['Disease'].values)))
x2=sorted(list(set(ds['Disease'].values)))

print(x1==x2)
# Out:
# True

# %% [markdown]
# s_pre diseases are same as main dataset diseases. for some cases p3 and p4 are not present but thats not a problem

# %% [markdown]
# ### symptom severity (s_sev)

# %%
# symptom severity
s_sev.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
s_sev.isnull().sum()
# Out:
# Symptom    0
# weight     0
# dtype: int64

# %% [markdown]
# ### can we use severity of symptom in model to predict ???

# %% [markdown]
# ## Save data , combine all 4 files

# %%
ds['Disease'] = ds['Disease'].apply(lambda i: i.strip())
s_des['Disease'] = s_des['Disease'].apply(lambda i: i.strip())
s_pre['Disease'] = s_pre['Disease'].apply(lambda i: i.strip())

# %%
ds = ds.fillna('')
s_sev = s_sev.fillna('')
s_pre = s_pre.fillna('')
s_des = s_des.fillna('')

# %%
# create a final database for further processing
# combine all 4 csv
w_cnt ,char_cnt =[],[]
final_data = []

for idx,row in ds.iterrows():
    dis_name = row['Disease'].lower()
    try:
        dis_desc = str(s_des[s_des['Disease']==row['Disease']]['Description'].values[0])
    except Exception as e:
        print(idx,dis_name)
        print(str(e))
    dis_symptoms = ""
    for i in range(1,18):
        x=row['Symptom_'+str(i)]
        if len(x)>0:
            dis_symptoms += " "+ str(x).replace('_',' ').replace('  ',' ').lower()
    temp_pre = s_pre[s_pre['Disease']==row['Disease']].drop(["Disease"],axis=1).values
    dis_precaution = list(temp_pre[0])
    
    # word and char cnt in dis symptoms (main feature for model)
    w_cnt.append(len(dis_symptoms.split(' ')))
    char_cnt.append(len(dis_symptoms))
    
    final_data.append([dis_name, dis_desc, dis_symptoms, dis_precaution])

print(len(final_data))
# Out:
# 4920

# %%
final_data[0]
# Out:
# ['fungal infection',
#  'In humans, fungal infections occur when an invading fungus takes over an area of the body and is too much for the immune system to handle. Fungi can live in the air, soil, water, and plants. There are also some fungi that live naturally in the human body. Like many microbes, there are helpful fungi and harmful fungi.',
#  ' itching  skin rash  nodal skin eruptions  dischromic patches',
#  ['bath twice',
#   'use detol or neem in bathing water',
#   'keep infected area dry',
#   'use clean cloths']]

# %%
# visualizing word and character counts in the combined symptoms  
x_r = [i for i in range(4920)]

plt.figure(figsize=(30,35))
plt.grid(True)
plt.subplot(2,1,1)
plt.plot(x_r,w_cnt)

plt.subplot(2,1,2)
plt.plot(x_r,char_cnt)
plt.show()

# %%
final_df = pd.DataFrame(final_data, columns=["dis_name","dis_description","dis_symptoms","dis_precaution"])
final_df.shape
# Out:
# (4920, 4)

# %% [markdown]
# ### add column for k fold

# %%
# from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
Y = final_df['dis_name']
for i, (_, v_ind) in enumerate(kf.split(final_df,Y)):
    final_df.loc[final_df.index[v_ind], 'kfold'] = i+1

# %%
print(final_df.shape)
final_df.head()
# Out:
# (4920, 5)
#            dis_name                                    dis_description  \
# 0  fungal infection  In humans, fungal infections occur when an inv...
# 1  fungal infection  In humans, fungal infections occur when an inv...
# 2  fungal infection  In humans, fungal infections occur when an inv...
# 3  fungal infection  In humans, fungal infections occur when an inv...
# 4  fungal infection  In humans, fungal infections occur when an inv...
#
#                                         dis_symptoms  \
# 0   itching  skin rash  nodal skin eruptions  dis...
# 1    skin rash  nodal skin eruptions  dischromic ...
# 2   itching  nodal skin eruptions  dischromic pat...
# 3             itching  skin rash  dischromic patches
# 4           itching  skin rash  nodal skin eruptions
#
#                                       dis_precaution  kfold
# 0  [bath twice, use detol or neem in bathing wate...    1.0
# 1  [bath twice, use detol or neem in bathing wate...    5.0
# 2  [bath twice, use detol or neem in bathing wate...    5.0
# 3  [bath twice, use detol or neem in bathing wate...    5.0
# 4  [bath twice, use detol or neem in bathing wate...    2.0

# %%
final_df['kfold'].value_counts()
# Out:
# 1.0    984
# 5.0    984
# 2.0    984
# 3.0    984
# 4.0    984
# Name: kfold, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(final_df['dis_name'].values)
final_df['encoded_dis_name'] = le.transform(final_df['dis_name'].values)

# %%
final_df.head()
# Out:
#            dis_name                                    dis_description  \
# 0  fungal infection  In humans, fungal infections occur when an inv...
# 1  fungal infection  In humans, fungal infections occur when an inv...
# 2  fungal infection  In humans, fungal infections occur when an inv...
# 3  fungal infection  In humans, fungal infections occur when an inv...
# 4  fungal infection  In humans, fungal infections occur when an inv...
#
#                                         dis_symptoms  \
# 0   itching  skin rash  nodal skin eruptions  dis...
# 1    skin rash  nodal skin eruptions  dischromic ...
# 2   itching  nodal skin eruptions  dischromic pat...
# 3             itching  skin rash  dischromic patches
# 4           itching  skin rash  nodal skin eruptions
#
#                                       dis_precaution  kfold  encoded_dis_name
# 0  [bath twice, use detol or neem in bathing wate...    1.0                15
# 1  [bath twice, use detol or neem in bathing wate...    5.0                15
# 2  [bath twice, use detol or neem in bathing wate...    5.0                15
# 3  [bath twice, use detol or neem in bathing wate...    5.0                15
# 4  [bath twice, use detol or neem in bathing wate...    2.0                15

# %%
final_df['encoded_dis_name'].value_counts().shape
# Out:
# (41,)

# %%
final_df['dis_description'].value_counts().shape
# Out:
# (41,)

# %%
final_df['dis_name'].value_counts().shape
# Out:
# (41,)

# %%
final_df.isnull().sum()
# Out:
# dis_name            0
# dis_description     0
# dis_symptoms        0
# dis_precaution      0
# kfold               0
# encoded_dis_name    0
# dtype: int64

# %%
temp_df = final_df.copy()

# %%
temp_df.columns
# Out:
# Index(['dis_name', 'dis_description', 'dis_symptoms', 'dis_precaution',
#        'kfold', 'encoded_dis_name'],
#       dtype='object')

# %%
temp_df.drop('dis_description',axis=1,inplace=True)
temp_df.head()
# Out:
#            dis_name                                       dis_symptoms  \
# 0  fungal infection   itching  skin rash  nodal skin eruptions  dis...
# 1  fungal infection    skin rash  nodal skin eruptions  dischromic ...
# 2  fungal infection   itching  nodal skin eruptions  dischromic pat...
# 3  fungal infection             itching  skin rash  dischromic patches
# 4  fungal infection           itching  skin rash  nodal skin eruptions
#
#                                       dis_precaution  kfold  encoded_dis_name
# 0  [bath twice, use detol or neem in bathing wate...    1.0                15
# 1  [bath twice, use detol or neem in bathing wate...    5.0                15
# 2  [bath twice, use detol or neem in bathing wate...    5.0                15
# 3  [bath twice, use detol or neem in bathing wate...    5.0                15
# 4  [bath twice, use detol or neem in bathing wate...    2.0                15

# %%
temp_df.drop_duplicates(subset=['dis_name'],inplace=True)
temp_df = temp_df.reset_index()
print(temp_df.columns)
temp_df.drop('index',axis=1,inplace=True)
temp_df
# Out:
# Index(['index', 'dis_name', 'dis_symptoms', 'dis_precaution', 'kfold',
#        'encoded_dis_name'],
#       dtype='object')
#                                    dis_name  \
# 0                          fungal infection
# 1                                   allergy
# 2                                      gerd
# 3                       chronic cholestasis
# 4                             drug reaction
# 5                       peptic ulcer diseae
# 6                                      aids
# 7                                  diabetes
# 8                           gastroenteritis
# 9                          bronchial asthma
# 10                             hypertension
# 11                                 migraine
# 12                     cervical spondylosis
# 13             paralysis (brain hemorrhage)
# 14                                 jaundice
# 15                                  malaria
# 16                              chicken pox
# 17                                   dengue
# 18                                  typhoid
# 19                              hepatitis a
# 20                              hepatitis b
# 21                              hepatitis c
# 22                              hepatitis d
# 23                              hepatitis e
# 24                      alcoholic hepatitis
# 25                             tuberculosis
# 26                              common cold
# 27                                pneumonia
# 28             dimorphic hemmorhoids(piles)
# 29                             heart attack
# 30                           varicose veins
# 31                           hypothyroidism
# 32                          hyperthyroidism
# 33                             hypoglycemia
# 34                          osteoarthristis
# 35                                arthritis
# 36  (vertigo) paroymsal  positional vertigo
# 37                                     acne
# 38                  urinary tract infection
# 39                                psoriasis
# 40                                 impetigo
#
#                                          dis_symptoms  \
# 0    itching  skin rash  nodal skin eruptions  dis...
# 1     continuous sneezing  shivering  chills  wate...
# 2     stomach pain  acidity  ulcers on tongue  vom...
# 3    itching  vomiting  yellowish skin  nausea  lo...
# 4    itching  skin rash  stomach pain  burning mic...
# 5     vomiting  loss of appetite  abdominal pain  ...
# 6     muscle wasting  patches in throat  high feve...
# 7     fatigue  weight loss  restlessness  lethargy...
# 8       vomiting  sunken eyes  dehydration  diarrhoea
# 9     fatigue  cough  high fever  breathlessness  ...
# 10    headache  chest pain  dizziness  loss of bal...
# 11    acidity  indigestion  headache  blurred and ...
# 12    back pain  weakness in limbs  neck pain  diz...
# 13    vomiting  headache  weakness of one body sid...
# 14   itching  vomiting  fatigue  weight loss  high...
# 15    chills  vomiting  high fever  sweating  head...
# 16   itching  skin rash  fatigue  lethargy  high f...
# 17    skin rash  chills  joint pain  vomiting  fat...
# 18    chills  vomiting  fatigue  high fever  nause...
# 19    joint pain  vomiting  yellowish skin  dark u...
# 20   itching  fatigue  lethargy  yellowish skin  d...
# 21    fatigue  yellowish skin  nausea  loss of app...
# 22    joint pain  vomiting  fatigue  yellowish ski...
# 23    joint pain  vomiting  fatigue  high fever  y...
# 24    vomiting  yellowish skin  abdominal pain  sw...
# 25    chills  vomiting  fatigue  weight loss  coug...
# 26    continuous sneezing  chills  fatigue  cough ...
# 27    chills  fatigue  cough  high fever  breathle...
# 28    constipation  pain during bowel movements  p...
# 29     vomiting  breathlessness  sweating  chest pain
# 30    fatigue  cramps  bruising  obesity  swollen ...
# 31    fatigue  weight gain  cold hands and feets  ...
# 32    fatigue  mood swings  weight loss  restlessn...
# 33    vomiting  fatigue  anxiety  sweating  headac...
# 34    joint pain  neck pain  knee pain  hip joint ...
# 35    muscle weakness  stiff neck  swelling joints...
# 36    vomiting  headache  nausea  spinning movemen...
# 37    skin rash  pus filled pimples  blackheads  s...
# 38    burning micturition  bladder discomfort  fou...
# 39    skin rash  joint pain  skin peeling  silver ...
# 40    skin rash  high fever  blister  red sore aro...
#
#                                        dis_precaution  kfold  encoded_dis_name
# 0   [bath twice, use detol or neem in bathing wate...    1.0                15
# 1   [apply calamine, cover area with bandage, , us...    3.0                 4
# 2   [avoid fatty spicy food, avoid lying down afte...    5.0                17
# 3   [cold baths, anti itch medicine, consult docto...    5.0                 9
# 4   [stop irritation, consult nearest hospital, st...    4.0                14
# 5   [avoid fatty spicy food, consume probiotic foo...    4.0                34
# 6   [avoid open cuts, wear ppe if possible, consul...    1.0                 2
# 7   [have balanced diet, exercise, consult doctor,...    4.0                12
# 8   [stop eating solid food for while, try taking ...    1.0                16
# 9   [switch to loose cloothing, take deep breaths,...    3.0                 6
# 10  [meditation, salt baths, reduce stress, get pr...    5.0                24
# 11  [meditation, reduce stress, use poloroid glass...    3.0                31
# 12  [use heating pad or cold pack, exercise, take ...    5.0                 7
# 13   [massage, eat healthy, exercise, consult doctor]    4.0                33
# 14  [drink plenty of water, consume milk thistle, ...    4.0                29
# 15  [Consult nearest hospital, avoid oily food, av...    2.0                30
# 16  [use neem in bathing , consume neem leaves, ta...    1.0                 8
# 17  [drink papaya leaf juice, avoid fatty spicy fo...    4.0                11
# 18  [eat high calorie vegitables, antiboitic thera...    4.0                38
# 19  [Consult nearest hospital, wash hands through,...    4.0                19
# 20  [consult nearest hospital, vaccination, eat he...    4.0                20
# 21  [Consult nearest hospital, vaccination, eat he...    1.0                21
# 22  [consult doctor, medication, eat healthy, foll...    4.0                22
# 23  [stop alcohol consumption, rest, consult docto...    3.0                23
# 24  [stop alcohol consumption, consult doctor, med...    3.0                 3
# 25    [cover mouth, consult doctor, medication, rest]    4.0                37
# 26  [drink vitamin c rich drinks, take vapour, avo...    1.0                10
# 27      [consult doctor, medication, rest, follow up]    3.0                35
# 28  [avoid fatty spicy food, consume witch hazel, ...    4.0                13
# 29  [call ambulance, chew or swallow asprin, keep ...    1.0                18
# 30  [lie down flat and raise the leg high, use oin...    5.0                40
# 31  [reduce stress, exercise, eat healthy, get pro...    1.0                27
# 32  [eat healthy, massage, use lemon balm, take ra...    1.0                25
# 33  [lie down on side, check in pulse, drink sugar...    3.0                26
# 34  [acetaminophen, consult nearest hospital, foll...    4.0                32
# 35  [exercise, use hot and cold therapy, try acupu...    3.0                 5
# 36  [lie down, avoid sudden change in body, avoid ...    5.0                 0
# 37  [bath twice, avoid fatty spicy food, drink ple...    5.0                 1
# 38  [drink plenty of water, increase vitamin c int...    1.0                39
# 39  [wash hands with warm soapy water, stop bleedi...    1.0                36
# 40  [soak affected area in warm water, use antibio...    2.0                28

# %%
final_df.to_csv('./../data/final_dataset_all.csv',index=False)
temp_df.to_csv('./../data/unique_diseases_info.csv',index=False)

# %%
# save label encoder
import numpy as np
np.save('./../label_enc_classes.npy', le.classes_)

# %%
# encoder = LabelEncoder()
# encoder.classes_ = numpy.load('classes.npy')
# # Now you should be able to use encoder
# # as you would do after `fit`

# %% [markdown]
# ### End of Notebook
